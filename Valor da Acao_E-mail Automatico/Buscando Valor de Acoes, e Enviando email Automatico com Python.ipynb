# %% [markdown]
# # Problema
#
# - Passo 1: Buscar dados dos valores das ações de forma automática no site do Yahoo Finanças
# - Passo 2: Gerar as análises solicitadas pelo gestor de forma automatica
# - Passo 3: Enviar um e-mail automaticamente para o gestor com o resultado das análises

# %% [markdown]
# # Passo 1

# %%
# !pip install yfinance

# %%
import yfinance

# %%
ticker = input("Digite a sigla da ação desejada: ")
dados = yfinance.Ticker(ticker).history("6mo")
fechamento = dados.Close
fechamento.plot()
# Out:
# Digite a sigla da ação desejada: PETR4.SA
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# # Variaveis das Cotações Passo 2
#
# Análises dos últimos 6 meses:
#
# - Cotação máxima no período
# - Cotação mínima
# - Cotação atual

# %%
maxima = fechamento.max()

# %%
minima = fechamento.min()

# %%
atual = fechamento[-1]

# %% [markdown]
# # Autogui Disparo de email automatico Passo 3
#
# - Abrir uma nova aba e digitar o endereço do gmail
# - Clicar no botão Escrever email
# - Preencher o email do destinatário
# - Preencher o Assunto do email
# - Escrever o email
# - Clicar no botão Enviar

# %%
# !pip install pyautogui
# Out:
# ...
#      ---------------------------------------- 59.0/59.0 kB 1.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...

# %%
# !pip install pyperclip

# %%
import pyautogui
import pyperclip

# %%
pyautogui.PAUSE = 1

pyautogui.hotkey("ctrl", "t")
pyperclip.copy("www.gmail.com")
pyautogui.hotkey("ctrl", "v")
pyautogui.hotkey("enter")

time.sleep(2)
pyautogui.click(x=-930, y=-29)

time.sleep(1.5)
pyperclip.copy("Cliente1@gmail.com")
pyautogui.hotkey("ctrl", "v")

pyautogui.hotkey("tab")

pyperclip.copy("Análises diárias")
pyautogui.hotkey("ctrl", "v")
pyautogui.hotkey("tab")

mensagem = f"""
Prezado cliente, seguem abaixo as Cotações da ação {ticker} na data de hoje:

Cotação Máxima: R$ {round(maxima,3)}
Cotação Mínima: R$ {round(minima,3)}
Cotação Atual: R$ {round(atual,3)}
"""
pyperclip.copy(mensagem)
pyautogui.hotkey("ctrl", "v")

pyautogui.click(x=-507, y=1611)

# %%
import time

time.sleep(5)

pyautogui.position()
# Out:
# Point(x=-774, y=-23)
